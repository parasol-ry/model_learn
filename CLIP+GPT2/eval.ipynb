# %%
import json
with open('predict_end.json') as f:
    id_caption_map = json.load(f)



# print(len(id_caption_map))
c = [{"image_id": int(idx), "caption": capition} for idx, capition in id_caption_map.items()]
c
# Out:
# [{'image_id': 203564,
#   'caption': 'A close up of a bicycle with a clock on it.'},
#  {'image_id': 179765,
#   'caption': 'A black motorcycle parked on the side of a driveway.'},
#  {'image_id': 322141,
#   'caption': 'A bathroom with a toilet and a blue toilet.'},
#  {'image_id': 16977, 'caption': 'A car and a horse are parked next to a car.'},
#  {'image_id': 106140,
#   'caption': 'An airplane that is taking off from a runway.'},
#  {'image_id': 571635, 'caption': 'A bathroom with a toilet and a sink.'},
#  {'image_id': 301837,
#   'caption': 'A modern kitchen with a white stove top and a sink.'},
#  {'image_id': 190236,
#   'caption': 'A cluttered office with two computers and a keyboard.'},
#  {'image_id': 315702,
#   'caption': 'A bathroom with a sink and a marble counter top.'},
#  {'image_id': 331352, 'caption': 'A white toilet sitting in a bathroom.'},
#  {'image_id': 517069,
#   'caption': 'A woman sitting on a sidewalk on a city street.'},
#  {'image_id': 189634,
# ...

# %%
with open("predict_eval_end.json", "w") as f:
    json.dump(c, f)

# %%
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap

annotation_file = '/data/qiaowei/coco2014/annotations/captions_val2014.json'
results_file = './predict_eval_end.json'

# create coco object and coco_result object
coco = COCO(annotation_file)
coco_result = coco.loadRes(results_file)

# create coco_eval object by taking coco and coco_result
coco_eval = COCOEvalCap(coco, coco_result)

# evaluate on a subset of images by setting
# coco_eval.params['image_id'] = coco_result.getImgIds()
# please remove this line when evaluating the full validation set
coco_eval.params['image_id'] = coco_result.getImgIds()

# # evaluate results
# # SPICE will take a few minutes the first time, but speeds up due to caching
coco_eval.evaluate()

# print output evaluation scores
for metric, score in coco_eval.eval.items():
    print(f'{metric}: {score:.3f}')
# Out:
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.08s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 2492309 tokens at 1895184.45 tokens per second.
# PTBTokenizer tokenized 477656 tokens at 1180461.66 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 397412, 'reflen': 389169, 'guess': [397412, 356908, 316404, 275900], 'correct': [289233, 156551, 74298, 33527]}
# ratio: 1.021181029321449
# Bleu_1: 0.728
# Bleu_2: 0.565
# Bleu_3: 0.422
# Bleu_4: 0.309
# computing METEOR score...
# METEOR: 0.262
# computing Rouge score...
# ROUGE_L: 0.544
# computing CIDEr score...
# CIDEr: 1.009
# computing SPICE score...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ...

# %%
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap

annotation_file = '/data/qiaowei/coco2014/annotations/captions_val2014.json'
results_file = 'predict_eval.json'

# create coco object and coco_result object
coco = COCO(annotation_file)
coco_result = coco.loadRes(results_file)

# create coco_eval object by taking coco and coco_result
coco_eval = COCOEvalCap(coco, coco_result)

# evaluate on a subset of images by setting
# coco_eval.params['image_id'] = coco_result.getImgIds()
# please remove this line when evaluating the full validation set
coco_eval.params['image_id'] = coco_result.getImgIds()

# evaluate results
# SPICE will take a few minutes the first time, but speeds up due to caching
coco_eval.evaluate()

# print output evaluation scores
for metric, score in coco_eval.eval.items():
    print(f'{metric}: {score:.3f}')
# Out:
# loading annotations into memory...
# Done (t=0.37s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.08s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 2492309 tokens at 1462166.02 tokens per second.
# PTBTokenizer tokenized 490007 tokens at 1258010.19 tokens per second.
# setting up scorers...
# computing Bleu score...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/renyi/workplace/ai-arcane/CLIP+GPT2/eval.ipynb Cell 4' in <cell line: 21>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bgpu/home/renyi/workplace/ai-arcane/CLIP%2BGPT2/eval.ipynb#ch0000003vscode-remote?line=16'>17</a> coco_eval.params['image_id'] = coco_result.getImgIds()
# ...

# %%
# !pwd
# Out:
# /home/renyi/workplace/ai-arcane/CLIP+GPT2

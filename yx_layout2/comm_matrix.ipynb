# %%
import pandas as pd

# %%
import json
from itertools import islice

with open("/data/medivh_data/workv2_sample.tagged.fixed.jsonl") as f:
    data = [json.loads(line) for line in islice(f, 20000,30000)]

# %%
df = pd.read_csv("/data/medivh_data/las.sample.part-1.meta.v2.tsv", sep="\t")
file_source_map = {file: source for file, source in zip(df.file, df.source)}

# %%
file_source_map = {file: source for file, source in zip(df.file, df.source)}

# %%
import pickle

with open("model/lgbm.pkl", "rb") as f:
    model = pickle.load(f)

with open("model/dtypes.pkl", "rb") as f:
    dtypes = pickle.load(f)

# %%
import pandas as pd
from latain.data import Block, BlockHandcraftRecord

# %%
import numpy as np

# %%
qcwy_a_xuen_dicts = [i for i in data if file_source_map[i["file"]] == "QCWY_A"][:2000]

# %%
def get_comm_matrix(xuen_dict):
    block = Block.from_dict(xuen_dict)
    flat_records, ids = BlockHandcraftRecord.from_block(block).to_flat_records()
    records = []
    records_span_idx = []
    for record, ((line_id1, span_id1, span_idx1), (line_id2, span_id2, span_idx2)) in zip(flat_records, ids):
        if line_id1 == line_id2:
            continue
        records.append(record)
        records_span_idx.append((span_idx1, span_idx2))
    _df = pd.DataFrame(records)
    X = _df.iloc[:, :-1].astype(dtypes)
    y = _df.iloc[:, -1]
    probs = model.predict_proba(X)[:, 1]
    num_spans = sum(len(i) for i in block)
    comm_matrix = np.zeros((num_spans, num_spans))
    for prob, (idx1, idx2) in zip(probs, records_span_idx):
        comm_matrix[idx1, idx2] = prob
    return comm_matrix + comm_matrix.T

# %%
from tqdm import tqdm

# %%
file_comm_matrix_map = {}
for xuen_dict in tqdm(qcwy_a_xuen_dicts):
    file = xuen_dict["file"]
    comm_matrix = get_comm_matrix(xuen_dict)
    file_comm_matrix_map[file] = comm_matrix
# Out:
# 100%|██████████| 2000/2000 [11:42<00:00,  2.85it/s]

# %%
from moka_tokenizer import moka_codec

# %%
def process_span(span: dict):
    output = {
        "tokens": [],
        "tags": [],
        "token_ids": []
    }
    
    for (subtext, _), tag in zip(span["text"], span["tags"]):
        if tag != "O":
            tag = tag[2:]
        _tokens, _indexes = moka_codec.encode(subtext)
        for _token, (_, _idx) in zip(_tokens, _indexes):
            output["tokens"].append(_token.chars)
            output["token_ids"].append(_idx)
            output["tags"].append(tag)
    return output


def xuen_dict_to_ner_record(xuen_dict):
    spans = []
    for line in xuen_dict["objs"]:
        for span in line:
            spans.append(process_span((span)))
    return spans

# %%
comm_records = []
for xuen_dict in qcwy_a_xuen_dicts:
    file = xuen_dict["file"]
    spans = xuen_dict_to_ner_record(xuen_dict)
    comm_matrix = file_comm_matrix_map[file]
    comm_records.append({
        "spans": spans,
        "comm_matrix": comm_matrix,
    })

# %%
import pickle

# %%
with open("data/comm_records.pkl", "wb") as f:
    pickle.dump(comm_records, f)

# %%
comm_records[0]
# Out:
# {'spans': [{'tokens': ['<', 'photo', '>'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [1481, 12118, 1494]},
#   {'tokens': ['最', '近', '工', '作'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [18599, 22005, 17691, 16180]},
#   {'tokens': ['最', '高', '学', '历', '/', '学', '位'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [18599, 22918, 17441, 16656, 303, 17441, 16167]},
#   {'tokens': ['职', '位', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [20754, 16167, 1435]},
#   {'tokens': ['主', '办', '会', '计'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [16004, 16533, 16143, 21583]},
#   {'tokens': ['专', '业', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [15976, 15983, 1435]},
#   {'tokens': ['财', '务', '管', '理'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [21766, 16536, 20382, 19760]},
#   {'tokens': ['公', '司', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [16382, 16720, 1435]},
#   {'tokens': ['美', '商', '希', '赫', '泵', '浦', '股', '份', '有', '限', '公', '司'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [20679,
#     16906,
#     17716,
#     21825,
#     19138,
#     19202,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720]},
#   {'tokens': ['学', '校', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [17441, 18732, 1435]},
#   {'tokens': ['圣', '安', '德', '鲁', '斯', '大', '学'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17077, 17458, 17906, 22949, 18455, 17248, 17441]},
#   {'tokens': ['行', '业', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [21395, 15983, 1435]},
#   {'tokens': ['机', '械', '/', '设', '备', '/', '重', '工'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [18625, 18789, 303, 21611, 17231, 303, 22225, 17691]},
#   {'tokens': ['学', '历', '/', '学', '位', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17441, 16656, 303, 17441, 16167, 1435]},
#   {'tokens': ['硕', '士'], 'tags': ['O', 'O'], 'token_ids': [20129, 17220]},
#   {'tokens': ['工', '作', '经', '验'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 20575, 22883]},
#   {'tokens': ['2', '0', '1', '7', '/', '6', '-', '2', '0', '1', '7', '/', '8'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     1102,
#     303,
#     991,
#     242,
#     547,
#     325,
#     436,
#     1102,
#     303,
#     1213]},
#   {'tokens': ['主', '办', '会', '计', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16004, 16533, 16143, 21583, 5178, 21766, 16536, 22157]},
#   {'tokens': ['美',
#     '商',
#     '希',
#     '赫',
#     '泵',
#     '浦',
#     '股',
#     '份',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '2',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [20679,
#     16906,
#     17716,
#     21825,
#     19138,
#     19202,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     547,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['机',
#     '械',
#     '/',
#     '设',
#     '备',
#     '/',
#     '重',
#     '工',
#     ' ',
#     '|',
#     ' ',
#     '少',
#     '于',
#     '5',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [18625,
#     18789,
#     303,
#     21611,
#     17231,
#     303,
#     22225,
#     17691,
#     9,
#     5178,
#     9,
#     17541,
#     16048,
#     880,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['申',
#     '报',
#     '营',
#     '业',
#     '税',
#     ',',
#     '综',
#     '所',
#     '税',
#     '与',
#     '二',
#     '代',
#     '健',
#     '保'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [19870,
#     18169,
#     21151,
#     15983,
#     20261,
#     218,
#     20610,
#     18114,
#     20261,
#     15972,
#     16046,
#     16110,
#     16301,
#     16240]},
#   {'tokens': ['帐',
#     '务',
#     '处',
#     '理',
#     ',',
#     '集',
#     '团',
#     '间',
#     '公',
#     '司',
#     '对',
#     '帐',
#     '与',
#     '差',
#     '旅',
#     '审',
#     '核'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17718,
#     16536,
#     17230,
#     19760,
#     218,
#     22628,
#     17044,
#     22524,
#     16382,
#     16720,
#     17521,
#     17718,
#     15972,
#     17697,
#     18465,
#     17475,
#     18739]},
#   {'tokens': ['零', '用', '金', '管', '理'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [22648, 19860, 22229, 20382, 19760]},
#   {'tokens': ['现', '金', '流', '量', '控', '管', '与', '预', '测'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [19723,
#     22229,
#     19176,
#     22227,
#     18300,
#     20382,
#     15972,
#     22753,
#     19184]},
#   {'tokens': ['赴', '银', '行', '办', '理', '业', '务'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [21829, 22402, 21395, 16533, 19760, 15983, 16536]},
#   {'tokens': ['下',
#     '属',
#     '人',
#     '数',
#     ':',
#     '1',
#     '人',
#     ' ',
#     ' ',
#     '|',
#     ' ',
#     ' ',
#     '汇',
#     '报',
#     '对',
#     '象',
#     ':',
#     'cfo',
#     ' ',
#     '|',
#     ' ',
#     ' ',
#     '离',
#     '职',
#     '原',
#     '因',
#     ':',
#     '公',
#     '司',
#     '迁',
#     '厂'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [15969,
#     17582,
#     16079,
#     18433,
#     1435,
#     436,
#     16079,
#     9,
#     9,
#     5178,
#     9,
#     9,
#     19041,
#     18169,
#     17521,
#     21717,
#     1435,
#     6759,
#     9,
#     5178,
#     9,
#     9,
#     20227,
#     20754,
#     16665,
#     17042,
#     1435,
#     16382,
#     16720,
#     21997,
#     16653]},
#   {'tokens': ['2', '0', '1', '6', '/', '9', '-', '2', '0', '1', '7', '/', '2'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     991,
#     303,
#     1324,
#     242,
#     547,
#     325,
#     436,
#     1102,
#     303,
#     547]},
#   {'tokens': ['财', '會', '副', '理', '|', '财', '会', '处'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [21766, 18600, 16521, 19760, 5178, 21766, 16143, 17230]},
#   {'tokens': ['德',
#     '爱',
#     '电',
#     '子',
#     '(',
#     '深',
#     '圳',
#     ')',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '5',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17906,
#     19594,
#     19872,
#     17424,
#     123,
#     19264,
#     17084,
#     137,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     880,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['仪',
#     '器',
#     '仪',
#     '表',
#     '/',
#     '工',
#     '业',
#     '自',
#     '动',
#     '化',
#     ' ',
#     '|',
#     ' ',
#     '1',
#     '0',
#     '0',
#     '0',
#     '-',
#     '5',
#     '0',
#     '0',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [16116,
#     17017,
#     16116,
#     21408,
#     303,
#     17691,
#     15983,
#     20904,
#     16542,
#     16590,
#     9,
#     5178,
#     9,
#     436,
#     325,
#     325,
#     325,
#     242,
#     880,
#     325,
#     325,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['o', '审', '核', '所', '有', '财', '务', '报', '表', '与', '凭', '证'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600,
#     17475,
#     18739,
#     18114,
#     18602,
#     21766,
#     16536,
#     18169,
#     21408,
#     15972,
#     16455,
#     21614]},
#   {'tokens': ['o', '财', '务', '分', '析'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600, 21766, 16536, 16471, 18669]},
#   {'tokens': ['o', '执', '行', '年', '度', '盘', '点', '与', '盘', '后', '报', '告'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600,
#     18133,
#     21395,
#     17753,
#     17787,
#     20009,
#     19492,
#     15972,
#     20009,
#     16736,
#     18169,
#     16776]},
#   {'tokens': ['o',
#     '执',
#     '行',
#     '2',
#     '0',
#     '1',
#     '6',
#     '年',
#     '度',
#     '深',
#     '圳',
#     '市',
#     '贸',
#     '易',
#     '信',
#     '贷',
#     '调',
#     '查',
#     '工',
#     '作'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18133,
#     21395,
#     547,
#     325,
#     436,
#     991,
#     17753,
#     17787,
#     19264,
#     17084,
#     17710,
#     21787,
#     18503,
#     16243,
#     21786,
#     21670,
#     18707,
#     17691,
#     16180]},
#   {'tokens': ['2', '0', '1', '5', '/', '6', '-', '2', '0', '1', '6', '/', '6'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     880,
#     303,
#     991,
#     242,
#     547,
#     325,
#     436,
#     991,
#     303,
#     991]},
#   {'tokens': ['主', '办', '會', '计', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16004, 16533, 18600, 21583, 5178, 21766, 16536, 22157]},
#   {'tokens': ['海',
#     '外',
#     '工',
#     '程',
#     '公',
#     '司',
#     '(',
#     '海',
#     '地',
#     '与',
#     '圣',
#     '文',
#     '森',
#     '特',
#     '分',
#     '公',
#     '司',
#     ')',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [19208,
#     17238,
#     17691,
#     20259,
#     16382,
#     16720,
#     123,
#     19208,
#     17083,
#     15972,
#     17077,
#     18438,
#     18811,
#     19623,
#     16471,
#     16382,
#     16720,
#     137,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     1519]},
#   {'tokens': ['建',
#     '筑',
#     '/',
#     '建',
#     '材',
#     '/',
#     '工',
#     '程',
#     ' ',
#     '|',
#     ' ',
#     '1',
#     '0',
#     '0',
#     '0',
#     '-',
#     '5',
#     '0',
#     '0',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17814,
#     20357,
#     303,
#     17814,
#     18636,
#     303,
#     17691,
#     20259,
#     9,
#     5178,
#     9,
#     436,
#     325,
#     325,
#     325,
#     242,
#     880,
#     325,
#     325,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['o',
#     '帐',
#     '务',
#     '处',
#     '理',
#     ',',
#     '成',
#     '本',
#     '控',
#     '制',
#     ',',
#     '薪',
#     '资',
#     '计',
#     '算',
#     ',',
#     '财',
#     '务',
#     '报',
#     '表',
#     '编',
#     '制',
#     '审',
#     '核',
#     '与',
#     '零',
#     '用',
#     '金',
#     '管',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     17718,
#     16536,
#     17230,
#     19760,
#     218,
#     18091,
#     18618,
#     18300,
#     16496,
#     218,
#     21243,
#     21798,
#     21583,
#     20379,
#     218,
#     21766,
#     16536,
#     18169,
#     21408,
#     20631,
#     16496,
#     17475,
#     18739,
#     15972,
#     22648,
#     19860,
#     22229,
#     20382,
#     19760]},
#   {'tokens': ['o',
#     '月',
#     '结',
#     '并',
#     '提',
#     '供',
#     '月',
#     '报',
#     '给',
#     '台',
#     '北',
#     '总',
#     '公',
#     '司'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18601,
#     20579,
#     17755,
#     18316,
#     16209,
#     18601,
#     18169,
#     20583,
#     16713,
#     16591,
#     17953,
#     16382,
#     16720]},
#   {'tokens': ['o',
#     '提',
#     '供',
#     '周',
#     '报',
#     '(',
#     '现',
#     '金',
#     '流',
#     '量',
#     '表',
#     ',',
#     '工',
#     '作',
#     '进',
#     '度',
#     '表',
#     ',',
#     '应',
#     '收',
#     '帐',
#     '款',
#     '帐',
#     '龄',
#     '分',
#     '析',
#     '表',
#     '与',
#     '未',
#     '来',
#     '两',
#     '周',
#     '资',
#     '金',
#     '流',
#     '动',
#     '表',
#     ')',
#     '给',
#     '台',
#     '北',
#     '总',
#     '公',
#     '司'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18316,
#     16209,
#     16791,
#     18169,
#     123,
#     19723,
#     22229,
#     19176,
#     22227,
#     21408,
#     218,
#     17691,
#     16180,
#     22014,
#     17787,
#     21408,
#     218,
#     17776,
#     18406,
#     17718,
#     18945,
#     17718,
#     23083,
#     16471,
#     18669,
#     21408,
#     15972,
#     18616,
#     18646,
#     15991,
#     16791,
#     21798,
#     22229,
#     19176,
#     16542,
#     21408,
#     137,
#     20583,
#     16713,
#     16591,
#     17953,
#     16382,
#     16720]},
#   {'tokens': ['o', '执', '行', '年', '度', '盘', '点'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600, 18133, 21395, 17753, 17787, 20009, 19492]},
#   {'tokens': ['o',
#     '每',
#     '月',
#     '申',
#     '报',
#     '健',
#     '保',
#     ',',
#     '增',
#     '值',
#     '税',
#     '与',
#     '薪',
#     '资',
#     '所',
#     '得',
#     '税'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18996,
#     18601,
#     19870,
#     18169,
#     16301,
#     16240,
#     218,
#     17208,
#     16288,
#     20261,
#     15972,
#     21243,
#     21798,
#     18114,
#     17893,
#     20261]},
#   {'tokens': ['o',
#     '每',
#     '年',
#     '申',
#     '报',
#     '营',
#     '利',
#     '事',
#     '业',
#     '所',
#     '得',
#     '税',
#     '与',
#     '年',
#     '检'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18996,
#     17753,
#     19870,
#     18169,
#     21151,
#     16491,
#     16045,
#     15983,
#     18114,
#     17893,
#     20261,
#     15972,
#     17753,
#     18794]},
#   {'tokens': ['o',
#     '分',
#     '公',
#     '司',
#     '及',
#     '台',
#     '北',
#     '总',
#     '公',
#     '司',
#     '往',
#     '来',
#     '帐',
#     '务',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     16471,
#     16382,
#     16720,
#     16681,
#     16713,
#     16591,
#     17953,
#     16382,
#     16720,
#     17876,
#     18646,
#     17718,
#     16536,
#     17230,
#     19760]},
#   {'tokens': ['o', '会', '计', '部', '门', '周', '会'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600, 16143, 21583, 22157, 22513, 16791, 16143]},
#   {'tokens': ['o',
#     '特',
#     '殊',
#     '事',
#     '项',
#     ':',
#     '分',
#     '公',
#     '司',
#     '设',
#     '立',
#     '及',
#     '与',
#     '税',
#     '局',
#     '交',
#     '涉',
#     '税',
#     '款',
#     '争',
#     '议',
#     '等'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     19623,
#     18976,
#     16045,
#     22743,
#     1435,
#     16471,
#     16382,
#     16720,
#     21611,
#     20312,
#     16681,
#     15972,
#     20261,
#     17565,
#     16065,
#     19213,
#     20261,
#     18945,
#     16043,
#     21596,
#     20352]},
#   {'tokens': ['最', '大', '成', '就'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [18599, 17248, 18091, 17555]},
#   {'tokens': ['成',
#     '功',
#     '说',
#     '服',
#     '税',
#     '局',
#     ',',
#     '免',
#     '缴',
#     '2',
#     '0',
#     '1',
#     '4',
#     '年',
#     '度',
#     '营',
#     '利',
#     '事',
#     '业',
#     '所',
#     '得',
#     '税',
#     '5',
#     '7',
#     '5',
#     ',',
#     '8',
#     '3',
#     '1',
#     '美',
#     '金',
#     '。'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [18091,
#     16534,
#     21656,
#     18606,
#     20261,
#     17565,
#     218,
#     16367,
#     20652,
#     547,
#     325,
#     436,
#     769,
#     17753,
#     17787,
#     21151,
#     16491,
#     16045,
#     15983,
#     18114,
#     17893,
#     20261,
#     880,
#     1102,
#     880,
#     218,
#     1213,
#     658,
#     436,
#     20679,
#     22229,
#     15726]},
#   {'tokens': ['2',
#     '0',
#     '1',
#     '3',
#     '/',
#     '1',
#     '1',
#     '-',
#     '2',
#     '0',
#     '1',
#     '5',
#     '/',
#     '5'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     658,
#     303,
#     436,
#     436,
#     242,
#     547,
#     325,
#     436,
#     880,
#     303,
#     880]},
#   {'tokens': ['会', '计', '管', '理', '师', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16143,
#     21583,
#     20382,
#     19760,
#     17715,
#     5178,
#     21766,
#     16536,
#     22157]},
#   {'tokens': ['达',
#     '方',
#     '电',
#     '子',
#     '股',
#     '份',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     '6',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [21996,
#     18460,
#     19872,
#     17424,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     991,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['计',
#     '算',
#     '机',
#     '硬',
#     '件',
#     ' ',
#     '|',
#     ' ',
#     '1',
#     '0',
#     '0',
#     '0',
#     '0',
#     '人',
#     '以',
#     '上',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [21583,
#     20379,
#     18625,
#     20135,
#     16122,
#     9,
#     5178,
#     9,
#     436,
#     325,
#     325,
#     325,
#     325,
#     16079,
#     16112,
#     15968,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工',
#     '作',
#     '描',
#     '述',
#     ':',
#     ' ',
#     'o',
#     '总',
#     '帐',
#     '/',
#     'ap',
#     '/',
#     'ar',
#     '/',
#     'fa',
#     '帐',
#     '务',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17691,
#     16180,
#     18315,
#     22027,
#     1435,
#     9,
#     11600,
#     17953,
#     17718,
#     303,
#     5833,
#     303,
#     5899,
#     303,
#     8459,
#     17718,
#     16536,
#     17230,
#     19760]},
#   {'tokens': ['o', '应', '收', '帐', '款', '催', '收', '与', '管', '理'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600,
#     17776,
#     18406,
#     17718,
#     18945,
#     16319,
#     18406,
#     15972,
#     20382,
#     19760]},
#   {'tokens': ['o',
#     '综',
#     '合',
#     '所',
#     '得',
#     '税',
#     '与',
#     '二',
#     '代',
#     '健',
#     '保',
#     '扣',
#     '缴',
#     '申',
#     '报',
#     '与',
#     '调',
#     '节',
#     '表',
#     '编',
#     '制'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     20610,
#     16730,
#     18114,
#     17893,
#     20261,
#     15972,
#     16046,
#     16110,
#     16301,
#     16240,
#     18130,
#     20652,
#     19870,
#     18169,
#     15972,
#     21670,
#     20963,
#     21408,
#     20631,
#     16496]},
#   {'tokens': ['o',
#     '进',
#     '项',
#     '税',
#     '媒',
#     '体',
#     '档',
#     '制',
#     '做',
#     '与',
#     '调',
#     '节',
#     '表',
#     '编',
#     '制'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     22014,
#     22743,
#     20261,
#     17388,
#     16172,
#     18766,
#     16496,
#     16298,
#     15972,
#     21670,
#     20963,
#     21408,
#     20631,
#     16496]},
#   {'tokens': ['2',
#     '0',
#     '1',
#     '1',
#     '/',
#     '1',
#     '2',
#     '-',
#     '2',
#     '0',
#     '1',
#     '3',
#     '/',
#     '1',
#     '0'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     436,
#     303,
#     436,
#     547,
#     242,
#     547,
#     325,
#     436,
#     658,
#     303,
#     436,
#     325]},
#   {'tokens': ['财', '务', '经', '理', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [21766, 16536, 20575, 19760, 5178, 21766, 16536, 22157]},
#   {'tokens': ['上',
#     '海',
#     '上',
#     '福',
#     '塑',
#     '料',
#     '制',
#     '品',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     '1',
#     '0',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [15968,
#     19208,
#     15968,
#     20218,
#     17186,
#     18445,
#     16496,
#     16843,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     436,
#     325,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['机',
#     '械',
#     '/',
#     '设',
#     '备',
#     '/',
#     '重',
#     '工',
#     ' ',
#     '|',
#     ' ',
#     '1',
#     '0',
#     '0',
#     '0',
#     '-',
#     '5',
#     '0',
#     '0',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [18625,
#     18789,
#     303,
#     21611,
#     17231,
#     303,
#     22225,
#     17691,
#     9,
#     5178,
#     9,
#     436,
#     325,
#     325,
#     325,
#     242,
#     880,
#     325,
#     325,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['o',
#     '审',
#     '核',
#     '各',
#     '项',
#     '传',
#     '票',
#     ',',
#     '费',
#     '用',
#     ',',
#     '付',
#     '款',
#     '单',
#     '据',
#     ',',
#     '银',
#     '行',
#     '调',
#     '节',
#     '表',
#     '与',
#     '财',
#     '务',
#     '报',
#     '表'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     17475,
#     18739,
#     16727,
#     22743,
#     16147,
#     20205,
#     218,
#     21788,
#     19860,
#     218,
#     16103,
#     18945,
#     16625,
#     18273,
#     218,
#     22402,
#     21395,
#     21670,
#     20963,
#     21408,
#     15972,
#     21766,
#     16536,
#     18169,
#     21408]},
#   {'tokens': ['o',
#     '内',
#     '外',
#     '帐',
#     '帐',
#     '务',
#     '处',
#     '理',
#     '及',
#     '与',
#     '台',
#     '湾',
#     '总',
#     '公',
#     '司',
#     '往',
#     '来',
#     '帐',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     16401,
#     17238,
#     17718,
#     17718,
#     16536,
#     17230,
#     19760,
#     16681,
#     15972,
#     16713,
#     19319,
#     17953,
#     16382,
#     16720,
#     17876,
#     18646,
#     17718,
#     17230,
#     19760]},
#   {'tokens': ['o',
#     '编',
#     '制',
#     '年',
#     '度',
#     '经',
#     '营',
#     '报',
#     '告',
#     ',',
#     '编',
#     '制',
#     '资',
#     '金',
#     '日',
#     '报',
#     '表'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     20631,
#     16496,
#     17753,
#     17787,
#     20575,
#     21151,
#     18169,
#     16776,
#     218,
#     20631,
#     16496,
#     21798,
#     22229,
#     18477,
#     18169,
#     21408]},
#   {'tokens': ['o',
#     '撰',
#     '写',
#     '盘',
#     '点',
#     '计',
#     '画',
#     '与',
#     '盘',
#     '点',
#     '结',
#     '果',
#     '之',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18377,
#     16413,
#     20009,
#     19492,
#     21583,
#     19876,
#     15972,
#     20009,
#     19492,
#     20579,
#     18675,
#     16015,
#     17230,
#     19760]},
#   {'tokens': ['o',
#     '办',
#     '理',
#     '公',
#     '司',
#     '固',
#     '定',
#     '资',
#     '产',
#     ',',
#     '存',
#     '货',
#     '投',
#     '保',
#     '与',
#     '贷',
#     '款',
#     '事',
#     '宜'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     16533,
#     19760,
#     16382,
#     16720,
#     17059,
#     17468,
#     21798,
#     16068,
#     218,
#     17430,
#     21771,
#     18158,
#     16240,
#     15972,
#     21786,
#     18945,
#     16045,
#     17470]},
#   {'tokens': ['下',
#     '属',
#     '人',
#     '数',
#     ':',
#     '6',
#     '人',
#     ' ',
#     ' ',
#     '|',
#     ' ',
#     ' ',
#     '汇',
#     '报',
#     '对',
#     '象',
#     ':',
#     '总',
#     '经',
#     '理',
#     ' ',
#     '|',
#     ' ',
#     ' ',
#     '离',
#     '职',
#     '原',
#     '因',
#     ':',
#     '回',
#     '台',
#     '照',
#     '顾',
#     '父',
#     '亲'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [15969,
#     17582,
#     16079,
#     18433,
#     1435,
#     991,
#     16079,
#     9,
#     9,
#     5178,
#     9,
#     9,
#     19041,
#     18169,
#     17521,
#     21717,
#     1435,
#     17953,
#     20575,
#     19760,
#     9,
#     5178,
#     9,
#     9,
#     20227,
#     20754,
#     16665,
#     17042,
#     1435,
#     17041,
#     16713,
#     19553,
#     22748,
#     19597,
#     16076]},
#   {'tokens': ['主', '要', '业', '绩', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [16004, 21475, 15983, 20597, 1435]},
#   {'tokens': ['将',
#     '公',
#     '司',
#     '电',
#     '话',
#     '费',
#     '每',
#     '月',
#     '降',
#     '低',
#     '约',
#     '2',
#     ',',
#     '0',
#     '0',
#     '0',
#     'rmb',
#     ',',
#     '每',
#     '年',
#     '带',
#     '来',
#     '3',
#     ',',
#     '0',
#     '0',
#     '0',
#     'rmb',
#     '购',
#     '物',
#     '卡',
#     '收',
#     '入',
#     '与',
#     '年',
#     '度',
#     '固',
#     '定',
#     '资',
#     '产',
#     '与',
#     '存',
#     '货',
#     '保',
#     '费',
#     '降',
#     '低',
#     '约',
#     '4',
#     '5',
#     ',',
#     '0',
#     '0',
#     '0',
#     'rm'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17532,
#     16382,
#     16720,
#     19872,
#     21635,
#     21788,
#     18996,
#     18601,
#     22577,
#     16168,
#     20540,
#     547,
#     218,
#     325,
#     325,
#     325,
#     13075,
#     218,
#     18996,
#     17753,
#     17728,
#     18646,
#     658,
#     218,
#     325,
#     325,
#     325,
#     13075,
#     21777,
#     19619,
#     16635,
#     18406,
#     16377,
#     15972,
#     17753,
#     17787,
#     17059,
#     17468,
#     21798,
#     16068,
#     15972,
#     17430,
#     21771,
#     16240,
#     21788,
#     22577,
#     16168,
#     20540,
#     769,
#     880,
#     218,
#     325,
#     325,
#     325,
#     13072]},
#   {'tokens': ['b', '。'], 'tags': ['O', 'O'], 'token_ids': [6149, 15726]},
#   {'tokens': ['2',
#     '0',
#     '1',
#     '0',
#     '/',
#     '1',
#     '1',
#     '-',
#     '2',
#     '0',
#     '1',
#     '1',
#     '/',
#     '1',
#     '1'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     325,
#     303,
#     436,
#     436,
#     242,
#     547,
#     325,
#     436,
#     436,
#     303,
#     436,
#     436]},
#   {'tokens': ['主', '办', '会', '计', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16004, 16533, 16143, 21583, 5178, 21766, 16536, 22157]},
#   {'tokens': ['福',
#     '来',
#     '(',
#     '上',
#     '海',
#     ')',
#     '国',
#     '际',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [20218,
#     18646,
#     123,
#     15968,
#     19208,
#     137,
#     17060,
#     22570,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     1519]},
#   {'tokens': ['房',
#     '地',
#     '产',
#     ' ',
#     '|',
#     ' ',
#     '少',
#     '于',
#     '5',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [18113,
#     17083,
#     16068,
#     9,
#     5178,
#     9,
#     17541,
#     16048,
#     880,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工',
#     '作',
#     '描',
#     '述',
#     ':',
#     ' ',
#     'o',
#     '一',
#     '般',
#     '帐',
#     '务',
#     '处',
#     '理',
#     '与',
#     '编',
#     '制',
#     '财',
#     '务',
#     '报',
#     '表'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17691,
#     16180,
#     18315,
#     22027,
#     1435,
#     9,
#     11600,
#     15961,
#     20935,
#     17718,
#     16536,
#     17230,
#     19760,
#     15972,
#     20631,
#     16496,
#     21766,
#     16536,
#     18169,
#     21408]},
#   {'tokens': ['o', '赴', '银', '行', '处', '理', '业', '务'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600, 21829, 22402, 21395, 17230, 19760, 15983, 16536]},
#   {'tokens': ['o',
#     '营',
#     '业',
#     '税',
#     '网',
#     '上',
#     '申',
#     '报',
#     '与',
#     '通',
#     '过',
#     '会',
#     '计',
#     '上',
#     '冈',
#     '证',
#     '会',
#     '计',
#     '基',
#     '础',
#     '科',
#     '目',
#     '考',
#     '试'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     21151,
#     15983,
#     20261,
#     20661,
#     15968,
#     19870,
#     18169,
#     15972,
#     22052,
#     22001,
#     16143,
#     21583,
#     15968,
#     16403,
#     21614,
#     16143,
#     21583,
#     17160,
#     20124,
#     20237,
#     20017,
#     20726,
#     21629]},
#   {'tokens': ['2',
#     '0',
#     '0',
#     '9',
#     '/',
#     '1',
#     '2',
#     '-',
#     '2',
#     '0',
#     '1',
#     '0',
#     '/',
#     '7'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     325,
#     1324,
#     303,
#     436,
#     547,
#     242,
#     547,
#     325,
#     436,
#     325,
#     303,
#     1102]},
#   {'tokens': ['专', '员', '|', '国', '际', '业', '务', '处'],
#    'tags': ['title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [15976, 16784, 5178, 17060, 22570, 15983, 16536, 17230]},
#   {'tokens': ['中',
#     '华',
#     '民',
#     '国',
#     '高',
#     '尔',
#     '夫',
#     '协',
#     '会',
#     ' ',
#     '[',
#     ' ',
#     '7',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [15997,
#     16618,
#     19011,
#     17060,
#     22918,
#     17543,
#     17251,
#     16619,
#     16143,
#     9,
#     1513,
#     9,
#     1102,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['非',
#     '营',
#     '利',
#     '组',
#     '织',
#     ' ',
#     '|',
#     ' ',
#     '少',
#     '于',
#     '5',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [22682,
#     21151,
#     16491,
#     20564,
#     20567,
#     9,
#     5178,
#     9,
#     17541,
#     16048,
#     880,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['o',
#     '编',
#     '制',
#     '选',
#     '手',
#     '出',
#     '国',
#     '比',
#     '赛',
#     '行',
#     '前',
#     '手',
#     '册',
#     '与',
#     '撰',
#     '写',
#     '新',
#     '闻',
#     '稿'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     20631,
#     16496,
#     22041,
#     18120,
#     16463,
#     17060,
#     18999,
#     21814,
#     21395,
#     16510,
#     18120,
#     16406,
#     15972,
#     18377,
#     16413,
#     18456,
#     22530,
#     20277]},
#   {'tokens': ['o',
#     '英',
#     '文',
#     '翻',
#     '译',
#     '与',
#     '其',
#     '他',
#     '秘',
#     '书',
#     '长',
#     '交',
#     '办',
#     '事',
#     '项'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     21024,
#     18438,
#     20720,
#     21627,
#     15972,
#     16392,
#     16101,
#     20240,
#     16035,
#     22500,
#     16065,
#     16533,
#     16045,
#     22743]},
#   {'tokens': ['2',
#     '0',
#     '0',
#     '6',
#     '/',
#     '1',
#     '1',
#     '-',
#     '2',
#     '0',
#     '0',
#     '7',
#     '/',
#     '1',
#     '1'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     325,
#     991,
#     303,
#     436,
#     436,
#     242,
#     547,
#     325,
#     325,
#     1102,
#     303,
#     436,
#     436]},
#   {'tokens': ['会', '计', '管', '理', '师', '|', '會', '计', '处'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16143,
#     21583,
#     20382,
#     19760,
#     17715,
#     5178,
#     18600,
#     21583,
#     17230]},
#   {'tokens': ['南',
#     '亚',
#     '科',
#     '技',
#     '股',
#     '份',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [16627,
#     16058,
#     20237,
#     18150,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     1519]},
#   {'tokens': ['通',
#     '信',
#     '/',
#     '电',
#     '信',
#     '/',
#     '网',
#     '络',
#     '设',
#     '备',
#     ' ',
#     '|',
#     ' ',
#     '1',
#     '0',
#     '0',
#     '0',
#     '0',
#     '人',
#     '以',
#     '上',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [22052,
#     16243,
#     303,
#     19872,
#     16243,
#     303,
#     20661,
#     20586,
#     21611,
#     17231,
#     9,
#     5178,
#     9,
#     436,
#     325,
#     325,
#     325,
#     325,
#     16079,
#     16112,
#     15968,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工',
#     '作',
#     '描',
#     '述',
#     ':',
#     ' ',
#     'o',
#     '传',
#     '票',
#     '制',
#     '作',
#     '与',
#     '票',
#     '据',
#     '审',
#     '核',
#     '等',
#     '一',
#     '般',
#     '帐',
#     '务',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17691,
#     16180,
#     18315,
#     22027,
#     1435,
#     9,
#     11600,
#     16147,
#     20205,
#     16496,
#     16180,
#     15972,
#     20205,
#     18273,
#     17475,
#     18739,
#     20352,
#     15961,
#     20935,
#     17718,
#     16536,
#     17230,
#     19760]},
#   {'tokens': ['o',
#     '两',
#     '个',
#     '月',
#     '一',
#     '次',
#     '去',
#     '国',
#     '税',
#     '局',
#     '营',
#     '业',
#     '税',
#     '申',
#     '报',
#     '与',
#     '协',
#     '助',
#     '会',
#     '计',
#     '师',
#     '查',
#     '帐'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     15991,
#     15995,
#     18601,
#     15961,
#     18936,
#     16673,
#     17060,
#     20261,
#     17565,
#     21151,
#     15983,
#     20261,
#     19870,
#     18169,
#     15972,
#     16619,
#     16543,
#     16143,
#     21583,
#     17715,
#     18707,
#     17718]},
#   {'tokens': ['o',
#     '母',
#     '子',
#     '公',
#     '司',
#     '应',
#     '收',
#     '与',
#     '应',
#     '付',
#     '帐',
#     '款',
#     '对',
#     '帐',
#     '与',
#     '内',
#     '购',
#     '作',
#     '业',
#     '合',
#     '约',
#     ',',
#     '订',
#     '单',
#     '等',
#     '相',
#     '关',
#     '凭',
#     '证',
#     '整',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18994,
#     17424,
#     16382,
#     16720,
#     17776,
#     18406,
#     15972,
#     17776,
#     16103,
#     17718,
#     18945,
#     17521,
#     17718,
#     15972,
#     16401,
#     21777,
#     16180,
#     15983,
#     16730,
#     20540,
#     218,
#     21584,
#     16625,
#     20352,
#     20023,
#     16389,
#     16455,
#     21614,
#     18435,
#     19760]},
#   {'tokens': ['最', '近', '工', '作'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [18599, 22005, 17691, 16180]},
#   {'tokens': ['最', '高', '学', '历', '/', '学', '位'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [18599, 22918, 17441, 16656, 303, 17441, 16167]},
#   {'tokens': ['职', '位', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [20754, 16167, 1435]},
#   {'tokens': ['主', '办', '会', '计'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [16004, 16533, 16143, 21583]},
#   {'tokens': ['专', '业', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [15976, 15983, 1435]},
#   {'tokens': ['财', '务', '管', '理'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [21766, 16536, 20382, 19760]},
#   {'tokens': ['公', '司', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [16382, 16720, 1435]},
#   {'tokens': ['美', '商', '希', '赫', '泵', '浦', '股', '份', '有', '限', '公', '司'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [20679,
#     16906,
#     17716,
#     21825,
#     19138,
#     19202,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720]},
#   {'tokens': ['学', '校', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [17441, 18732, 1435]},
#   {'tokens': ['圣', '安', '德', '鲁', '斯', '大', '学'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17077, 17458, 17906, 22949, 18455, 17248, 17441]},
#   {'tokens': ['行', '业', ':'],
#    'tags': ['O', 'O', 'O'],
#    'token_ids': [21395, 15983, 1435]},
#   {'tokens': ['机', '械', '/', '设', '备', '/', '重', '工'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [18625, 18789, 303, 21611, 17231, 303, 22225, 17691]},
#   {'tokens': ['学', '历', '/', '学', '位', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17441, 16656, 303, 17441, 16167, 1435]},
#   {'tokens': ['硕', '士'], 'tags': ['O', 'O'], 'token_ids': [20129, 17220]},
#   {'tokens': ['工', '作', '经', '验'],
#    'tags': ['O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 20575, 22883]},
#   {'tokens': ['2', '0', '1', '7', '/', '6', '-', '2', '0', '1', '7', '/', '8'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     1102,
#     303,
#     991,
#     242,
#     547,
#     325,
#     436,
#     1102,
#     303,
#     1213]},
#   {'tokens': ['主', '办', '会', '计', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16004, 16533, 16143, 21583, 5178, 21766, 16536, 22157]},
#   {'tokens': ['美',
#     '商',
#     '希',
#     '赫',
#     '泵',
#     '浦',
#     '股',
#     '份',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '2',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [20679,
#     16906,
#     17716,
#     21825,
#     19138,
#     19202,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     547,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['机',
#     '械',
#     '/',
#     '设',
#     '备',
#     '/',
#     '重',
#     '工',
#     ' ',
#     '|',
#     ' ',
#     '少',
#     '于',
#     '5',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [18625,
#     18789,
#     303,
#     21611,
#     17231,
#     303,
#     22225,
#     17691,
#     9,
#     5178,
#     9,
#     17541,
#     16048,
#     880,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['申',
#     '报',
#     '营',
#     '业',
#     '税',
#     ',',
#     '综',
#     '所',
#     '税',
#     '与',
#     '二',
#     '代',
#     '健',
#     '保'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [19870,
#     18169,
#     21151,
#     15983,
#     20261,
#     218,
#     20610,
#     18114,
#     20261,
#     15972,
#     16046,
#     16110,
#     16301,
#     16240]},
#   {'tokens': ['帐',
#     '务',
#     '处',
#     '理',
#     ',',
#     '集',
#     '团',
#     '间',
#     '公',
#     '司',
#     '对',
#     '帐',
#     '与',
#     '差',
#     '旅',
#     '审',
#     '核'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17718,
#     16536,
#     17230,
# ...
#     17787,
#     20575,
#     21151,
#     18169,
#     16776,
#     218,
#     20631,
#     16496,
#     21798,
#     22229,
#     18477,
#     18169,
#     21408]},
#   {'tokens': ['o',
#     '撰',
#     '写',
#     '盘',
#     '点',
#     '计',
#     '画',
#     '与',
#     '盘',
#     '点',
#     '结',
#     '果',
#     '之',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18377,
#     16413,
#     20009,
#     19492,
#     21583,
#     19876,
#     15972,
#     20009,
#     19492,
#     20579,
#     18675,
#     16015,
#     17230,
#     19760]},
#   {'tokens': ['o',
#     '办',
#     '理',
#     '公',
#     '司',
#     '固',
#     '定',
#     '资',
#     '产',
#     ',',
#     '存',
#     '货',
#     '投',
#     '保',
#     '与',
#     '贷',
#     '款',
#     '事',
#     '宜'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     16533,
#     19760,
#     16382,
#     16720,
#     17059,
#     17468,
#     21798,
#     16068,
#     218,
#     17430,
#     21771,
#     18158,
#     16240,
#     15972,
#     21786,
#     18945,
#     16045,
#     17470]},
#   {'tokens': ['下',
#     '属',
#     '人',
#     '数',
#     ':',
#     '6',
#     '人',
#     ' ',
#     ' ',
#     '|',
#     ' ',
#     ' ',
#     '汇',
#     '报',
#     '对',
#     '象',
#     ':',
#     '总',
#     '经',
#     '理',
#     ' ',
#     '|',
#     ' ',
#     ' ',
#     '离',
#     '职',
#     '原',
#     '因',
#     ':',
#     '回',
#     '台',
#     '照',
#     '顾',
#     '父',
#     '亲'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [15969,
#     17582,
#     16079,
#     18433,
#     1435,
#     991,
#     16079,
#     9,
#     9,
#     5178,
#     9,
#     9,
#     19041,
#     18169,
#     17521,
#     21717,
#     1435,
#     17953,
#     20575,
#     19760,
#     9,
#     5178,
#     9,
#     9,
#     20227,
#     20754,
#     16665,
#     17042,
#     1435,
#     17041,
#     16713,
#     19553,
#     22748,
#     19597,
#     16076]},
#   {'tokens': ['主', '要', '业', '绩', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [16004, 21475, 15983, 20597, 1435]},
#   {'tokens': ['将',
#     '公',
#     '司',
#     '电',
#     '话',
#     '费',
#     '每',
#     '月',
#     '降',
#     '低',
#     '约',
#     '2',
#     ',',
#     '0',
#     '0',
#     '0',
#     'rmb',
#     ',',
#     '每',
#     '年',
#     '带',
#     '来',
#     '3',
#     ',',
#     '0',
#     '0',
#     '0',
#     'rmb',
#     '购',
#     '物',
#     '卡',
#     '收',
#     '入',
#     '与',
#     '年',
#     '度',
#     '固',
#     '定',
#     '资',
#     '产',
#     '与',
#     '存',
#     '货',
#     '保',
#     '费',
#     '降',
#     '低',
#     '约',
#     '4',
#     '5',
#     ',',
#     '0',
#     '0',
#     '0',
#     'rm'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17532,
#     16382,
#     16720,
#     19872,
#     21635,
#     21788,
#     18996,
#     18601,
#     22577,
#     16168,
#     20540,
#     547,
#     218,
#     325,
#     325,
#     325,
#     13075,
#     218,
#     18996,
#     17753,
#     17728,
#     18646,
#     658,
#     218,
#     325,
#     325,
#     325,
#     13075,
#     21777,
#     19619,
#     16635,
#     18406,
#     16377,
#     15972,
#     17753,
#     17787,
#     17059,
#     17468,
#     21798,
#     16068,
#     15972,
#     17430,
#     21771,
#     16240,
#     21788,
#     22577,
#     16168,
#     20540,
#     769,
#     880,
#     218,
#     325,
#     325,
#     325,
#     13072]},
#   {'tokens': ['b', '。'], 'tags': ['O', 'O'], 'token_ids': [6149, 15726]},
#   {'tokens': ['2',
#     '0',
#     '1',
#     '0',
#     '/',
#     '1',
#     '1',
#     '-',
#     '2',
#     '0',
#     '1',
#     '1',
#     '/',
#     '1',
#     '1'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     436,
#     325,
#     303,
#     436,
#     436,
#     242,
#     547,
#     325,
#     436,
#     436,
#     303,
#     436,
#     436]},
#   {'tokens': ['主', '办', '会', '计', '|', '财', '务', '部'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16004, 16533, 16143, 21583, 5178, 21766, 16536, 22157]},
#   {'tokens': ['福',
#     '来',
#     '(',
#     '上',
#     '海',
#     ')',
#     '国',
#     '际',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [20218,
#     18646,
#     123,
#     15968,
#     19208,
#     137,
#     17060,
#     22570,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     1519]},
#   {'tokens': ['房',
#     '地',
#     '产',
#     ' ',
#     '|',
#     ' ',
#     '少',
#     '于',
#     '5',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [18113,
#     17083,
#     16068,
#     9,
#     5178,
#     9,
#     17541,
#     16048,
#     880,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工',
#     '作',
#     '描',
#     '述',
#     ':',
#     ' ',
#     'o',
#     '一',
#     '般',
#     '帐',
#     '务',
#     '处',
#     '理',
#     '与',
#     '编',
#     '制',
#     '财',
#     '务',
#     '报',
#     '表'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17691,
#     16180,
#     18315,
#     22027,
#     1435,
#     9,
#     11600,
#     15961,
#     20935,
#     17718,
#     16536,
#     17230,
#     19760,
#     15972,
#     20631,
#     16496,
#     21766,
#     16536,
#     18169,
#     21408]},
#   {'tokens': ['o', '赴', '银', '行', '处', '理', '业', '务'],
#    'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#    'token_ids': [11600, 21829, 22402, 21395, 17230, 19760, 15983, 16536]},
#   {'tokens': ['o',
#     '营',
#     '业',
#     '税',
#     '网',
#     '上',
#     '申',
#     '报',
#     '与',
#     '通',
#     '过',
#     '会',
#     '计',
#     '上',
#     '冈',
#     '证',
#     '会',
#     '计',
#     '基',
#     '础',
#     '科',
#     '目',
#     '考',
#     '试'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     21151,
#     15983,
#     20261,
#     20661,
#     15968,
#     19870,
#     18169,
#     15972,
#     22052,
#     22001,
#     16143,
#     21583,
#     15968,
#     16403,
#     21614,
#     16143,
#     21583,
#     17160,
#     20124,
#     20237,
#     20017,
#     20726,
#     21629]},
#   {'tokens': ['2',
#     '0',
#     '0',
#     '9',
#     '/',
#     '1',
#     '2',
#     '-',
#     '2',
#     '0',
#     '1',
#     '0',
#     '/',
#     '7'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     325,
#     1324,
#     303,
#     436,
#     547,
#     242,
#     547,
#     325,
#     436,
#     325,
#     303,
#     1102]},
#   {'tokens': ['专', '员', '|', '国', '际', '业', '务', '处'],
#    'tags': ['title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [15976, 16784, 5178, 17060, 22570, 15983, 16536, 17230]},
#   {'tokens': ['中',
#     '华',
#     '民',
#     '国',
#     '高',
#     '尔',
#     '夫',
#     '协',
#     '会',
#     ' ',
#     '[',
#     ' ',
#     '7',
#     '个',
#     '月',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [15997,
#     16618,
#     19011,
#     17060,
#     22918,
#     17543,
#     17251,
#     16619,
#     16143,
#     9,
#     1513,
#     9,
#     1102,
#     15995,
#     18601,
#     1519]},
#   {'tokens': ['非',
#     '营',
#     '利',
#     '组',
#     '织',
#     ' ',
#     '|',
#     ' ',
#     '少',
#     '于',
#     '5',
#     '0',
#     '人',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [22682,
#     21151,
#     16491,
#     20564,
#     20567,
#     9,
#     5178,
#     9,
#     17541,
#     16048,
#     880,
#     325,
#     16079,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工', '作', '描', '述', ':'],
#    'tags': ['O', 'O', 'O', 'O', 'O'],
#    'token_ids': [17691, 16180, 18315, 22027, 1435]},
#   {'tokens': ['o',
#     '编',
#     '制',
#     '选',
#     '手',
#     '出',
#     '国',
#     '比',
#     '赛',
#     '行',
#     '前',
#     '手',
#     '册',
#     '与',
#     '撰',
#     '写',
#     '新',
#     '闻',
#     '稿'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     20631,
#     16496,
#     22041,
#     18120,
#     16463,
#     17060,
#     18999,
#     21814,
#     21395,
#     16510,
#     18120,
#     16406,
#     15972,
#     18377,
#     16413,
#     18456,
#     22530,
#     20277]},
#   {'tokens': ['o',
#     '英',
#     '文',
#     '翻',
#     '译',
#     '与',
#     '其',
#     '他',
#     '秘',
#     '书',
#     '长',
#     '交',
#     '办',
#     '事',
#     '项'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     21024,
#     18438,
#     20720,
#     21627,
#     15972,
#     16392,
#     16101,
#     20240,
#     16035,
#     22500,
#     16065,
#     16533,
#     16045,
#     22743]},
#   {'tokens': ['2',
#     '0',
#     '0',
#     '6',
#     '/',
#     '1',
#     '1',
#     '-',
#     '2',
#     '0',
#     '0',
#     '7',
#     '/',
#     '1',
#     '1'],
#    'tags': ['timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange',
#     'timeRange'],
#    'token_ids': [547,
#     325,
#     325,
#     991,
#     303,
#     436,
#     436,
#     242,
#     547,
#     325,
#     325,
#     1102,
#     303,
#     436,
#     436]},
#   {'tokens': ['会', '计', '管', '理', '师', '|', '會', '计', '处'],
#    'tags': ['title',
#     'title',
#     'title',
#     'title',
#     'title',
#     'O',
#     'depart',
#     'depart',
#     'depart'],
#    'token_ids': [16143,
#     21583,
#     20382,
#     19760,
#     17715,
#     5178,
#     18600,
#     21583,
#     17230]},
#   {'tokens': ['南',
#     '亚',
#     '科',
#     '技',
#     '股',
#     '份',
#     '有',
#     '限',
#     '公',
#     '司',
#     ' ',
#     '[',
#     ' ',
#     '1',
#     '年',
#     ']'],
#    'tags': ['company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'company',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [16627,
#     16058,
#     20237,
#     18150,
#     20791,
#     16129,
#     18602,
#     22578,
#     16382,
#     16720,
#     9,
#     1513,
#     9,
#     436,
#     17753,
#     1519]},
#   {'tokens': ['通',
#     '信',
#     '/',
#     '电',
#     '信',
#     '/',
#     '网',
#     '络',
#     '设',
#     '备',
#     ' ',
#     '|',
#     ' ',
#     '1',
#     '0',
#     '0',
#     '0',
#     '0',
#     '人',
#     '以',
#     '上',
#     ' ',
#     '|',
#     ' ',
#     '外',
#     '资',
#     '(',
#     '非',
#     '欧',
#     '美',
#     ')'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [22052,
#     16243,
#     303,
#     19872,
#     16243,
#     303,
#     20661,
#     20586,
#     21611,
#     17231,
#     9,
#     5178,
#     9,
#     436,
#     325,
#     325,
#     325,
#     325,
#     16079,
#     16112,
#     15968,
#     9,
#     5178,
#     9,
#     17238,
#     21798,
#     123,
#     22682,
#     18940,
#     20679,
#     137]},
#   {'tokens': ['工',
#     '作',
#     '描',
#     '述',
#     ':',
#     ' ',
#     'o',
#     '传',
#     '票',
#     '制',
#     '作',
#     '与',
#     '票',
#     '据',
#     '审',
#     '核',
#     '等',
#     '一',
#     '般',
#     '帐',
#     '务',
#     '处',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [17691,
#     16180,
#     18315,
#     22027,
#     1435,
#     9,
#     11600,
#     16147,
#     20205,
#     16496,
#     16180,
#     15972,
#     20205,
#     18273,
#     17475,
#     18739,
#     20352,
#     15961,
#     20935,
#     17718,
#     16536,
#     17230,
#     19760]},
#   {'tokens': ['o',
#     '两',
#     '个',
#     '月',
#     '一',
#     '次',
#     '去',
#     '国',
#     '税',
#     '局',
#     '营',
#     '业',
#     '税',
#     '申',
#     '报',
#     '与',
#     '协',
#     '助',
#     '会',
#     '计',
#     '师',
#     '查',
#     '帐'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     15991,
#     15995,
#     18601,
#     15961,
#     18936,
#     16673,
#     17060,
#     20261,
#     17565,
#     21151,
#     15983,
#     20261,
#     19870,
#     18169,
#     15972,
#     16619,
#     16543,
#     16143,
#     21583,
#     17715,
#     18707,
#     17718]},
#   {'tokens': ['o',
#     '母',
#     '子',
#     '公',
#     '司',
#     '应',
#     '收',
#     '与',
#     '应',
#     '付',
#     '帐',
#     '款',
#     '对',
#     '帐',
#     '与',
#     '内',
#     '购',
#     '作',
#     '业',
#     '合',
#     '约',
#     ',',
#     '订',
#     '单',
#     '等',
#     '相',
#     '关',
#     '凭',
#     '证',
#     '整',
#     '理'],
#    'tags': ['O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O',
#     'O'],
#    'token_ids': [11600,
#     18994,
#     17424,
#     16382,
#     16720,
#     17776,
#     18406,
#     15972,
#     17776,
#     16103,
#     17718,
#     18945,
#     17521,
#     17718,
#     15972,
#     16401,
#     21777,
#     16180,
#     15983,
#     16730,
#     20540,
#     218,
#     21584,
#     16625,
#     20352,
#     20023,
#     16389,
#     16455,
#     21614,
#     18435,
#     19760]}],
#  'comm_matrix': array([[0.        , 0.60239705, 0.51842509, ..., 0.02117822, 0.02758879,
#          0.08201466],
#         [0.60239705, 0.        , 0.        , ..., 0.02702595, 0.02352109,
#          0.03841559],
#         [0.51842509, 0.        , 0.        , ..., 0.0601093 , 0.01787125,
#          0.04158031],
#         ...,
#         [0.02117822, 0.02702595, 0.0601093 , ..., 0.        , 0.91100606,
#          0.73921165],
#         [0.02758879, 0.02352109, 0.01787125, ..., 0.91100606, 0.        ,
#          0.93044779],
#         [0.08201466, 0.03841559, 0.04158031, ..., 0.73921165, 0.93044779,
#          0.        ]])}

# %%
xuen_dict_to_ner_record(xuen_dict)
# Out:
# [{'tokens': ['最', '近', '工', '作'],
#   'tags': ['O', 'O', 'O', 'O'],
#   'token_ids': [18599, 22005, 17691, 16180]},
#  {'tokens': ['最', '高', '学', '历', '/', '学', '位'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [18599, 22918, 17441, 16656, 303, 17441, 16167]},
#  {'tokens': ['职', '位', ':'],
#   'tags': ['O', 'O', 'O'],
#   'token_ids': [20754, 16167, 1435]},
#  {'tokens': ['售', '前', '/', '售', '后', '技', '术', '支', '持', '工', '程', '师'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [16894,
#    16510,
#    303,
#    16894,
#    16736,
#    18150,
#    18621,
#    18405,
#    18225,
#    17691,
#    20259,
#    17715]},
#  {'tokens': ['专', '业', ':'],
#   'tags': ['O', 'O', 'O'],
#   'token_ids': [15976, 15983, 1435]},
#  {'tokens': ['英', '语'], 'tags': ['O', 'O'], 'token_ids': [21024, 21650]},
#  {'tokens': ['公', '司', ':'],
#   'tags': ['O', 'O', 'O'],
#   'token_ids': [16382, 16720, 1435]},
#  {'tokens': ['boe', '合', '肥', '京', '东', '方', '视', '讯'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [6384, 16730, 20794, 16073, 15985, 18460, 21493, 21597]},
#  {'tokens': ['学', '校', ':'],
#   'tags': ['O', 'O', 'O'],
#   'token_ids': [17441, 18732, 1435]},
#  {'tokens': ['安', '徽', '新', '华', '学', '院'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17458, 17908, 18456, 16618, 17441, 22585]},
#  {'tokens': ['行', '业', ':'],
#   'tags': ['O', 'O', 'O'],
#   'token_ids': [21395, 15983, 1435]},
#  {'tokens': ['电', '子', '技', '术', '/', '半', '导', '体', '/', '集', '成', '电', '路'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [19872,
#    17424,
#    18150,
#    18621,
#    303,
#    16615,
#    17524,
#    16172,
#    303,
#    22628,
#    18091,
#    19872,
#    21866]},
#  {'tokens': ['学', '历', '/', '学', '位', ':'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17441, 16656, 303, 17441, 16167, 1435]},
#  {'tokens': ['本', '科'], 'tags': ['O', 'O'], 'token_ids': [18618, 20237]},
#  {'tokens': ['工', '作', '经', '验'],
#   'tags': ['O', 'O', 'O', 'O'],
#   'token_ids': [17691, 16180, 20575, 22883]},
#  {'tokens': ['2', '0', '1', '8', '/', '8', '-', '至', '今'],
#   'tags': ['timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange'],
#   'token_ids': [547, 325, 436, 1213, 303, 1213, 242, 20907, 16091]},
#  {'tokens': ['售',
#    '前',
#    '/',
#    '售',
#    '后',
#    '技',
#    '术',
#    '支',
#    '持',
#    '工',
#    '程',
#    '师',
#    '|',
#    'qa'],
#   'tags': ['title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'O',
#    'depart'],
#   'token_ids': [16894,
#    16510,
#    303,
#    16894,
#    16736,
#    18150,
#    18621,
#    18405,
#    18225,
#    17691,
#    20259,
#    17715,
#    5178,
#    12592]},
#  {'tokens': ['boe',
#    '合',
#    '肥',
#    '京',
#    '东',
#    '方',
#    '视',
#    '讯',
#    ' ',
#    '[',
#    ' ',
#    '1',
#    '年',
#    '8',
#    '个',
#    '月',
#    ']'],
#   'tags': ['company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [6384,
#    16730,
#    20794,
#    16073,
#    15985,
#    18460,
#    21493,
#    21597,
#    9,
#    1513,
#    9,
#    436,
#    17753,
#    1213,
#    15995,
#    18601,
#    1519]},
#  {'tokens': ['电',
#    '子',
#    '技',
#    '术',
#    '/',
#    '半',
#    '导',
#    '体',
#    '/',
#    '集',
#    '成',
#    '电',
#    '路',
#    ' ',
#    '|',
#    ' ',
#    '1',
#    '0',
#    '0',
#    '0',
#    '-',
#    '5',
#    '0',
#    '0',
#    '0',
#    '人',
#    ' ',
#    '|',
#    ' ',
#    '国',
#    '企'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [19872,
#    17424,
#    18150,
#    18621,
#    303,
#    16615,
#    17524,
#    16172,
#    303,
#    22628,
#    18091,
#    19872,
#    21866,
#    9,
#    5178,
#    9,
#    436,
#    325,
#    325,
#    325,
#    242,
#    880,
#    325,
#    325,
#    325,
#    16079,
#    9,
#    5178,
#    9,
#    17060,
#    16131]},
#  {'tokens': ['工', '作', '描', '述', ':'],
#   'tags': ['O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17691, 16180, 18315, 22027, 1435]},
#  {'tokens': ['售',
#    '后',
#    '备',
#    '件',
#    '出',
#    '货',
#    '计',
#    '划',
#    '安',
#    '排',
#    ',',
#    '各',
#    '类',
#    '客',
#    '诉',
#    '处',
#    '理'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [16894,
#    16736,
#    17231,
#    16122,
#    16463,
#    21771,
#    21583,
#    16478,
#    17458,
#    18291,
#    218,
#    16727,
#    20427,
#    17476,
#    21621,
#    17230,
#    19760]},
#  {'tokens': ['2', '0', '1', '7', '/', '5', '-', '2', '0', '1', '8', '/', '4'],
#   'tags': ['timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange'],
#   'token_ids': [547,
#    325,
#    436,
#    1102,
#    303,
#    880,
#    242,
#    547,
#    325,
#    436,
#    1213,
#    303,
#    769]},
#  {'tokens': ['物', '流', '专', '员', '/', '助', '理', '|', '生', '产', '部'],
#   'tags': ['title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'O',
#    'depart',
#    'depart',
#    'depart'],
#   'token_ids': [19619,
#    19176,
#    15976,
#    16784,
#    303,
#    16543,
#    19760,
#    5178,
#    19854,
#    16068,
#    22157]},
#  {'tokens': ['双',
#    '钱',
#    '集',
#    '团',
#    '安',
#    '徽',
#    '回',
#    '力',
#    '轮',
#    '胎',
#    '有',
#    '限',
#    '公',
#    '司',
#    ' ',
#    '[',
#    ' ',
#    '1',
#    '1',
#    '个',
#    '月',
#    ']'],
#   'tags': ['company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [16683,
#    22346,
#    22628,
#    17044,
#    17458,
#    17908,
#    17041,
#    16531,
#    21945,
#    20815,
#    18602,
#    22578,
#    16382,
#    16720,
#    9,
#    1513,
#    9,
#    436,
#    436,
#    15995,
#    18601,
#    1519]},
#  {'tokens': ['汽',
#    '车',
#    ' ',
#    '|',
#    ' ',
#    '5',
#    '0',
#    '0',
#    '-',
#    '1',
#    '0',
#    '0',
#    '0',
#    '人',
#    ' ',
#    '|',
#    ' ',
#    '合',
#    '资'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [19069,
#    21938,
#    9,
#    5178,
#    9,
#    880,
#    325,
#    325,
#    242,
#    436,
#    325,
#    325,
#    325,
#    16079,
#    9,
#    5178,
#    9,
#    16730,
#    21798]},
#  {'tokens': ['工', '作', '描', '述', ':'],
#   'tags': ['O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17691, 16180, 18315, 22027, 1435]},
#  {'tokens': ['负',
#    '责',
#    '全',
#    '厂',
#    '轮',
#    '胎',
#    '内',
#    '销',
#    '外',
#    '贸',
#    '承',
#    '运',
#    '发',
#    '货',
#    '计',
#    '划',
#    '安',
#    '排',
#    ',',
#    '过',
#    '程',
#    '监',
#    '控',
#    ',',
#    '库',
#    '存',
#    '监',
#    '控',
#    ',',
#    '供',
#    '应',
#    '链',
#    'sap',
#    '线',
#    '上',
#    '操',
#    '作',
#    ',',
#    '与',
#    '市',
#    '场',
#    '销',
#    '售',
#    '部',
#    '对',
#    '接',
#    '处',
#    '理',
#    '异'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [21763,
#    21767,
#    16379,
#    16653,
#    21945,
#    20815,
#    16401,
#    22410,
#    17238,
#    21787,
#    18149,
#    22004,
#    16688,
#    21771,
#    21583,
#    16478,
#    17458,
#    18291,
#    218,
#    22001,
#    20259,
#    20004,
#    18300,
#    218,
#    17775,
#    17430,
#    20004,
#    18300,
#    218,
#    16209,
#    17776,
#    22408,
#    13236,
#    20561,
#    15968,
#    18387,
#    16180,
#    218,
#    15972,
#    17710,
#    17085,
#    22410,
#    16894,
#    22157,
#    17521,
#    18299,
#    17230,
#    19760,
#    17818]},
#  {'tokens': ['常', ',', '对', '承', '运', '商', '进', '行', '考', '核', '。'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17737,
#    218,
#    17521,
#    18149,
#    22004,
#    16906,
#    22014,
#    21395,
#    20726,
#    18739,
#    15726]},
#  {'tokens': ['2', '0', '1', '1', '/', '9', '-', '2', '0', '1', '7', '/', '4'],
#   'tags': ['timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange'],
#   'token_ids': [547,
#    325,
#    436,
#    436,
#    303,
#    1324,
#    242,
#    547,
#    325,
#    436,
#    1102,
#    303,
#    769]},
#  {'tokens': ['行', '政', '专', '员', '/', '助', '理', '|', '生', '产', '部'],
#   'tags': ['title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'title',
#    'O',
#    'depart',
#    'depart',
#    'depart'],
#   'token_ids': [21395,
#    18411,
#    15976,
#    16784,
#    303,
#    16543,
#    19760,
#    5178,
#    19854,
#    16068,
#    22157]},
#  {'tokens': ['双',
#    '钱',
#    '集',
#    '团',
#    '安',
#    '徽',
#    '回',
#    '力',
#    '轮',
#    '胎',
#    '有',
#    '限',
#    '公',
#    '司',
#    ' ',
#    '[',
#    ' ',
#    '5',
#    '年',
#    '7',
#    '个',
#    '月',
#    ']'],
#   'tags': ['company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [16683,
#    22346,
#    22628,
#    17044,
#    17458,
#    17908,
#    17041,
#    16531,
#    21945,
#    20815,
#    18602,
#    22578,
#    16382,
#    16720,
#    9,
#    1513,
#    9,
#    880,
#    17753,
#    1102,
#    15995,
#    18601,
#    1519]},
#  {'tokens': ['汽',
#    '车',
#    ' ',
#    '|',
#    ' ',
#    '1',
#    '0',
#    '0',
#    '0',
#    '-',
#    '5',
#    '0',
#    '0',
#    '0',
#    '人',
#    ' ',
#    '|',
#    ' ',
#    '合',
#    '资'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [19069,
#    21938,
#    9,
#    5178,
#    9,
#    436,
#    325,
#    325,
#    325,
#    242,
#    880,
#    325,
#    325,
#    325,
#    16079,
#    9,
#    5178,
#    9,
#    16730,
#    21798]},
#  {'tokens': ['工', '作', '描', '述', ':'],
#   'tags': ['O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17691, 16180, 18315, 22027, 1435]},
#  {'tokens': ['主',
#    '要',
#    '负',
#    '责',
#    '办',
#    '公',
#    '室',
#    '内',
#    '勤',
#    ';',
#    '工',
#    '厂',
#    '部',
#    '门',
#    '级',
#    '会',
#    '议',
#    '组',
#    '织',
#    ',',
#    '会',
#    '议',
#    '纪',
#    '要',
#    '记',
#    '录',
#    '以',
#    '及',
#    '对',
#    '于',
#    '问',
#    '题',
#    '点',
#    '记',
#    '录',
#    '追',
#    '踪',
#    ',',
#    '督',
#    '促',
#    '整',
#    '改',
#    ';',
#    '全',
#    '厂',
#    '行',
#    '政',
#    '值',
#    '班',
#    '问',
#    '题'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [16004,
#    21475,
#    21763,
#    21767,
#    16533,
#    16382,
#    17478,
#    16401,
#    16573,
#    1463,
#    17691,
#    16653,
#    22157,
#    22513,
#    20541,
#    16143,
#    21596,
#    20564,
#    20567,
#    218,
#    16143,
#    21596,
#    20543,
#    21475,
#    21598,
#    17854,
#    16112,
#    16681,
#    17521,
#    16048,
#    22518,
#    22768,
#    19492,
#    21598,
#    17854,
#    22033,
#    21883,
#    218,
#    20055,
#    16226,
#    18435,
#    18408,
#    1463,
#    16379,
#    16653,
#    21395,
#    18411,
#    16288,
#    19750,
#    22518,
#    22768]},
#  {'tokens': ['点',
#    '汇',
#    '总',
#    '以',
#    '及',
#    '督',
#    '促',
#    '各',
#    '部',
#    '门',
#    '按',
#    '纳',
#    '期',
#    '给',
#    '出',
#    '整',
#    '改',
#    '措',
#    '施',
#    ';',
#    '各',
#    '部',
#    '门',
#    '请',
#    '购',
#    '生',
#    '产',
#    '工',
#    '器',
#    '具',
#    '物',
#    '料',
#    '消',
#    '耗',
#    'sap',
#    '系',
#    '统',
#    '录',
#    '入',
#    '以',
#    '及',
#    '管',
#    '控',
#    ',',
#    '物',
#    '料',
#    '主',
#    '数',
#    '据'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [19492,
#    19041,
#    17953,
#    16112,
#    16681,
#    20055,
#    16226,
#    16727,
#    22157,
#    22513,
#    18232,
#    20552,
#    18613,
#    20583,
#    16463,
#    18435,
#    18408,
#    18303,
#    18462,
#    1463,
#    16727,
#    22157,
#    22513,
#    21659,
#    21777,
#    19854,
#    16068,
#    17691,
#    17017,
#    16393,
#    19619,
#    18445,
#    19212,
#    20737,
#    13236,
#    20465,
#    20589,
#    17854,
#    16377,
#    16112,
#    16681,
#    20382,
#    18300,
#    218,
#    19619,
#    18445,
#    16004,
#    18433,
#    18273]},
#  {'tokens': ['维',
#    '护',
#    ';',
#    '生',
#    '产',
#    '计',
#    '划',
#    '条',
#    '线',
#    'sap',
#    '录',
#    '入',
#    '并',
#    '月',
#    '结',
#    '关',
#    '键',
#    '用',
#    '戸',
#    '职',
#    '责',
#    '。',
#    '成',
#    '本',
#    '统',
#    '计',
#    ':',
#    '负',
#    '责',
#    '对',
#    '于',
#    '各',
#    '生',
#    '产',
#    '部',
#    '门',
#    '材',
#    '料',
#    '损',
#    '耗',
#    '数',
#    '据',
#    '收',
#    '集',
#    '统',
#    '计',
#    ',',
#    '督',
#    '促'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [20605,
#    18168,
#    1463,
#    19854,
#    16068,
#    21583,
#    16478,
#    18645,
#    20561,
#    13236,
#    17854,
#    16377,
#    17755,
#    18601,
#    20579,
#    16389,
#    22446,
#    19860,
#    18111,
#    20754,
#    21767,
#    15726,
#    18091,
#    18618,
#    20589,
#    21583,
#    1435,
#    21763,
#    21767,
#    17521,
#    16048,
#    16727,
#    19854,
#    16068,
#    22157,
#    22513,
#    18636,
#    18445,
#    18265,
#    20737,
#    18433,
#    18273,
#    18406,
#    22628,
#    20589,
#    21583,
#    218,
#    20055,
#    16226]},
#  {'tokens': ['各',
#    '工',
#    '区',
#    '对',
#    '于',
#    '超',
#    '标',
#    '项',
#    '目',
#    '进',
#    '行',
#    '分',
#    '析',
#    '。'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [16727,
#    17691,
#    16603,
#    17521,
#    16048,
#    21835,
#    18719,
#    22743,
#    20017,
#    22014,
#    21395,
#    16471,
#    18669,
#    15726]},
#  {'tokens': ['汇', '报', '对', '象', ':', '部', '门', '总', '监'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [19041, 18169, 17521, 21717, 1435, 22157, 22513, 17953, 20004]},
#  {'tokens': ['2', '0', '0', '9', '/', '3', '-', '2', '0', '0', '9', '/', '8'],
#   'tags': ['timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange',
#    'timeRange'],
#   'token_ids': [547,
#    325,
#    325,
#    1324,
#    303,
#    658,
#    242,
#    547,
#    325,
#    325,
#    1324,
#    303,
#    1213]},
#  {'tokens': ['小', '学', '教', '师'],
#   'tags': ['title', 'title', 'title', 'title'],
#   'token_ids': [17540, 17441, 18425, 17715]},
#  {'tokens': ['英',
#    '语',
#    '课',
#    '后',
#    '培',
#    '训',
#    '辅',
#    '导',
#    ' ',
#    '[',
#    ' ',
#    '5',
#    '个',
#    '月',
#    ']'],
#   'tags': ['company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'company',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [21024,
#    21650,
#    21666,
#    16736,
#    17159,
#    21595,
#    21962,
#    17524,
#    9,
#    1513,
#    9,
#    880,
#    15995,
#    18601,
#    1519]},
#  {'tokens': ['教', '育', '/', '培', '训', '/', '院', '校'],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'token_ids': [18425, 20800, 303, 17159, 21595, 303, 22585, 18732]},
#  {'tokens': ['工', '作', '描', '述', ':'],
#   'tags': ['O', 'O', 'O', 'O', 'O'],
#   'token_ids': [17691, 16180, 18315, 22027, 1435]},
#  {'tokens': ['英',
#    '语',
#    '教',
#    '育',
#    '培',
#    '训',
#    ',',
#    '教',
#    '授',
#    '新',
#    '课',
#    ',',
#    '功',
#    '课',
#    '辅',
#    '导',
#    '。'],
#   'tags': ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   'token_ids': [21024,
#    21650,
#    18425,
#    20800,
#    17159,
#    21595,
#    218,
#    18425,
#    18284,
#    18456,
#    21666,
#    218,
#    16534,
#    21666,
#    21962,
#    17524,
#    15726]}]

# %%
xuen_dict["objs"][1]
# Out:
# [{'pos': [41.75, 168.74999618530273, 68.75013732910156, 182.07000350952148],
#   'fsize': 9.0,
#   'font': 'NotoSansCJKsc-Regular',
#   'color': [102, 102, 102],
#   'bidx': 9,
#   'text': [['职', '<KEYW>,<CJK>'], ['位', '<KEYW>,<CJK>'], [':', '<POS>']],
#   'tags': ['O', 'O', 'O'],
#   'cats': 'Work,Work'},
#  {'pos': [105.5, 168.74999618530273, 208.02871704101562, 182.07000350952148],
#   'fsize': 9.0,
#   'font': 'NotoSansCJKsc-Regular',
#   'color': [51, 51, 51],
#   'bidx': 11,
#   'text': [['售', '<CJK>'],
#    ['前', '<CJK>'],
#    ['/', '<POS>'],
#    ['售', '<CJK>,<TIL>'],
#    ['后', '<CJK>,<TIL>'],
#    ['技', '<CJK>,<TIL>'],
#    ['术', '<CJK>,<TIL>'],
#    ['支', '<CJK>,<TIL>'],
#    ['持', '<CJK>,<TIL>'],
#    ['工', '<CJK>,<TIL>'],
#    ['程', '<CJK>,<TIL>'],
#    ['师', '<CJK>,<TIL>']],
#   'tags': ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   'cats': 'Work,Work'},
#  {'pos': [305.0, 168.74999618530273, 332.0001220703125, 182.07000350952148],
#   'fsize': 9.0,
#   'font': 'NotoSansCJKsc-Regular',
#   'color': [102, 102, 102],
#   'bidx': 10,
#   'text': [['专', '<CJK>'], ['业', '<CJK>'], [':', '<POS>']],
#   'tags': ['O', 'O', 'O'],
#   'cats': 'Edu,Edu'},
#  {'pos': [368.75, 168.74999618530273, 386.75006103515625, 182.07000350952148],
#   'fsize': 9.0,
#   'font': 'NotoSansCJKsc-Regular',
#   'color': [51, 51, 51],
#   'bidx': 10,
#   'text': [['英', '<CJK>'], ['语', '<CJK>']],
#   'tags': ['O', 'O'],
#   'cats': 'Edu,Edu'}]

# %%
get_comm_matrix(qcwy_a_xuen_dicts[0])
# Out:
# array([[0.        , 0.60239705, 0.51842509, ..., 0.02117822, 0.02758879,
#         0.08201466],
#        [0.60239705, 0.        , 0.        , ..., 0.02702595, 0.02352109,
#         0.03841559],
#        [0.51842509, 0.        , 0.        , ..., 0.0601093 , 0.01787125,
#         0.04158031],
#        ...,
#        [0.02117822, 0.02702595, 0.0601093 , ..., 0.        , 0.91100606,
#         0.73921165],
#        [0.02758879, 0.02352109, 0.01787125, ..., 0.91100606, 0.        ,
#         0.93044779],
#        [0.08201466, 0.03841559, 0.04158031, ..., 0.73921165, 0.93044779,
#         0.        ]])

# %%
spans = [j for i in block for j in i]

# %%
spans[55]
# Out:
# Span(pos=Position(left=300.4773254394531, top=948.3636494318645, right=384.1754150390625, down=961.5829945246379), fsize=8.931989669799805, font='NotoSansCJKsc-Bold', color=Color(r=0, g=0, b=0), tokens=['财', '务', '助', '理', '/', '文', '员', ' (', '兼', '职', ')'], token_tags=['<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<POS>', '<CJK>', '<CJK>', '<POS>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<POS>'], text='财务助理/文员 (兼职)', tag='title')

# %%
spans[8]
# Out:
# Span(pos=Position(left=82.38790893554688, top=161.57968521118164, right=157.34567260742188, down=174.79903030395508), fsize=8.931989669799805, font='NotoSansCJKsc-Regular', color=Color(r=0, g=0, b=0), tokens=['物', '业', '管', '理', '/', '商', '业', '中', '心'], token_tags=['<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<POS>', '<CJK>,<DPT>', '<CJK>,<DPT>', '<CJK>,<DPT>', '<CJK>,<DPT>'], text='物业管理/商业中心', tag='')

# %%
import sys
sys.path.insert(0, "/home/wangyuxin/workspace/resume-meta-guesser/guesser")
from mrd import Block as Mblock
import rich

# %%
spans[20]
# Out:
# Span(pos=Position(left=300.4773254394531, top=544.1665992736816, right=354.0696105957031, down=557.3858985900879), fsize=8.931989669799805, font='NotoSansCJKsc-Bold', color=Color(r=0, g=0, b=0), tokens=['财', '务', '会', '计', '专', '员'], token_tags=['<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>', '<CJK>,<TIL>'], text='财务会计专员', tag='title')

# %%
rich.print(Mblock.from_mrd_record(xuen_dict))
# Out:
# 最近工作        [ 2个月]        学历
# 公 司:        广州市宁骏物业管理有限公司        学 历:        本科
# 行 业:        物业管理/商业中心        专 业:        财务管理
# 职 位:        财务会计专员        学 校:        嘉应学院
# 工作经验
# 2017 /5--2017 /7:广州市宁骏物业管理有限公司 (1000-5000人)[ 2个月 ]
# 所属行业:        物业管理/商业中心
# 财务部        财务会计专员
# 1.项目运营分析;
# 2.审核项目费用报销;项目收入入账核算,项目年度预算编制;
# 3.收银系统各类操作的审核,调整,确保数据,资料的准确性;
# 4.开具及审核增值税发票,保管发票资料;
# 5.项目提交总部各种收费数据申请表的审核;
# 6.前台收银的培训工作;
# 7.协同行政对仓库物资及固定资产进行盘点,检查。
# 2016 /7--2017 /4:格兰仕(中山)家用电器有限公司 (1000-5000人)[ 9个月 ]
# 所属行业:        家具/家电/玩具/礼品
# 财务部        会计
# 财务系统 SAP系统
# 1,负责增值税,企业所得税,个税,废弃基金等国地税各项税金计算,申报,缴款及财务报表报送,备案等涉税
# 持日常联系沟通;
# 2,发票领购,开具,保管;抵扣认证进项发票,变更信息,开具纳税证明等;
# 3,负责固定资产的购建,折旧,转让,报废的审核及记账工作;负责固定资产盘点工作;
# 4,负责物料账月结,订单成本差异分析,发布每月计划作业价格及投入产出监控等成本工作;
# 5,负责统计公司的产量及产值,能源消耗等统计工作,报送统计办,与统计办,经信局等部门实时保持沟通与
# 6,月末车间及仓库库存盘点,核对供应商往来,签订内部公司租赁合同,申报资料及会计凭证整理存档;
# 7,完成领导安排其他事项;
# 2016 /2--2016 /4:深圳市斯沃得商贸有限公司 (50-150人)[ 2个月 ]
# 所属行业:        快速消费品(食品,饮料,化妆品)
# 财务部        财务助理/文员 (兼职)
# 实习期:
# 学习开具增值税专用发票,核算产品销售成本及人员工资,费用报销的审核;
# 学习公司全盘账务,用财务软件(金蝶)处理,出具月度利润表及费用明细表;
# 月末盘点仓库库存和跟进公司往来账及完成上级安排的其他工作
# 2015 /7--2015 /8:梅州市梅江区会计代理事务所 (少于50人)[ 1个月 ]
# 所属行业:        会计/审计
# 财务        财务助理/文员 (兼职)
# 负责数据录入,填写收据及各类申请表,整理文件
# 2014 /8--2014 /8:恒大冰泉集团[ 一个月内]
# 所属行业:        快速消费品(食品,饮料,化妆品)
# 销售部        其他 (兼职)
# 负责摊位促销活动安排,活动开展,为顾客讲解恒大冰泉,负责促销相关数据整理
# 2014 /7--2014 /7:鸿艺集团[ 一个月内]
# 所属行业:        房地产
# 宣传部        其他 (兼职)
# 带队为客戸介绍威尼斯样板房开盘日活动;
# 安排组员完成活动的相关事项,包括引导客戸,介绍楼盘,人力宣传等
# 2012 /9--2016 /6        嘉应学院        财务管理        本科
